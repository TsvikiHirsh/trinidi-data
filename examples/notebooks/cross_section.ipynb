# %% [markdown]
# Demo: `cross_section` Module
# ============================
# This script illustrates the functionality of the `trinidi.cross_section` submodule.

# %%
import numpy as np
import matplotlib.pyplot as plt
from trinidi import cross_section, util
from copy import deepcopy

# %% [markdown]
# Available Isotopes
# ------------------
# First we demonstrate how to display available and select isotopes and display their energy ranges.
#
# The `cross_section.info` function prints out info for all isotopes.

# %%
cross_section.info()
# Out:
# H-1	10.0 µeV to 20.0 MeV
# H-2	10.0 µeV to 150.0 MeV
# H-3	10.0 µeV to 20.0 MeV
# He-3	10.0 µeV to 20.0 MeV
# He-4	10.0 µeV to 20.0 MeV
# Li-6	10.0 µeV to 20.0 MeV
# Li-7	10.0 µeV to 20.0 MeV
# Be-7	10.0 µeV to 20.0 MeV
# Be-9	10.0 µeV to 20.0 MeV
# B-11	10.0 µeV to 20.0 MeV
# C-12	10.0 µeV to 150.0 MeV
# C-13	10.0 µeV to 20.0 MeV
# N-14	10.0 µeV to 150.0 MeV
# N-15	10.0 µeV to 20.0 MeV
# O-16	10.0 µeV to 150.0 MeV
# O-17	10.0 µeV to 20.0 MeV
# O-18	10.0 µeV to 20.0 MeV
# F-19	10.0 µeV to 20.0 MeV
# Ne-20	10.0 µeV to 200.0 MeV
# Ne-21	10.0 µeV to 200.0 MeV
# Ne-22	10.0 µeV to 200.0 MeV
# Na-22	10.0 µeV to 20.0 MeV
# Na-23	10.0 µeV to 20.0 MeV
# Mg-24	10.0 µeV to 20.0 MeV
# Mg-25	10.0 µeV to 20.0 MeV
# Mg-26	10.0 µeV to 20.0 MeV
# Al-27	10.0 µeV to 150.0 MeV
# Si-28	10.0 µeV to 150.0 MeV
# Si-29	10.0 µeV to 150.0 MeV
# Si-30	10.0 µeV to 150.0 MeV
# Si-31	10.0 µeV to 20.0 MeV
# Si-32	10.0 µeV to 20.0 MeV
# P-31	10.0 µeV to 150.0 MeV
# S-32	10.0 µeV to 20.0 MeV
# S-33	10.0 µeV to 20.0 MeV
# S-34	10.0 µeV to 20.0 MeV
# S-35	10.0 µeV to 20.0 MeV
# S-36	10.0 µeV to 20.0 MeV
# Cl-35	10.0 µeV to 20.0 MeV
# Cl-36	10.0 µeV to 20.0 MeV
# Cl-37	10.0 µeV to 20.0 MeV
# Ar-36	10.0 µeV to 20.0 MeV
# Ar-37	10.0 µeV to 200.0 MeV
# Ar-38	10.0 µeV to 20.0 MeV
# Ar-39	10.0 µeV to 20.0 MeV
# Ar-40	10.0 µeV to 20.0 MeV
# Ar-41	10.0 µeV to 200.0 MeV
# K-39	10.0 µeV to 20.0 MeV
# K-40	10.0 µeV to 20.0 MeV
# K-41	10.0 µeV to 20.0 MeV
# Ca-40	10.0 µeV to 200.0 MeV
# Ca-41	10.0 µeV to 20.0 MeV
# Ca-42	10.0 µeV to 200.0 MeV
# Ca-43	10.0 µeV to 200.0 MeV
# Ca-44	10.0 µeV to 200.0 MeV
# Ca-45	10.0 µeV to 200.0 MeV
# Ca-46	10.0 µeV to 200.0 MeV
# Ca-47	10.0 µeV to 200.0 MeV
# Ca-48	10.0 µeV to 200.0 MeV
# Sc-45	10.0 µeV to 20.0 MeV
# Ti-46	10.0 µeV to 20.0 MeV
# Ti-47	10.0 µeV to 20.0 MeV
# Ti-48	10.0 µeV to 20.0 MeV
# Ti-49	10.0 µeV to 20.0 MeV
# Ti-50	10.0 µeV to 20.0 MeV
# V-49	10.0 µeV to 20.0 MeV
# V-50	10.0 µeV to 20.0 MeV
# V-51	10.0 µeV to 20.0 MeV
# Cr-50	10.0 µeV to 150.0 MeV
# Cr-51	10.0 µeV to 200.0 MeV
# Cr-52	10.0 µeV to 150.0 MeV
# Cr-53	10.0 µeV to 150.0 MeV
# Cr-54	10.0 µeV to 150.0 MeV
# Mn-54	10.0 µeV to 200.0 MeV
# Mn-55	10.0 µeV to 60.0 MeV
# Fe-54	10.0 µeV to 150.0 MeV
# Fe-55	10.0 µeV to 200.0 MeV
# Fe-56	10.0 µeV to 150.0 MeV
# Fe-57	10.0 µeV to 150.0 MeV
# Fe-58	10.0 µeV to 150.0 MeV
# Co-58	10.0 µeV to 20.0 MeV
# Co-59	10.0 µeV to 20.0 MeV
# Ni-58	10.0 µeV to 150.0 MeV
# Ni-59	10.0 µeV to 20.0 MeV
# Ni-60	10.0 µeV to 150.0 MeV
# Ni-61	10.0 µeV to 150.0 MeV
# Ni-62	10.0 µeV to 150.0 MeV
# Ni-63	10.0 µeV to 20.0 MeV
# Ni-64	10.0 µeV to 150.0 MeV
# Cu-63	10.0 µeV to 150.0 MeV
# Cu-64	10.0 µeV to 20.0 MeV
# Cu-65	10.0 µeV to 150.0 MeV
# Zn-64	10.0 µeV to 20.0 MeV
# Zn-65	10.0 µeV to 20.0 MeV
# Zn-66	10.0 µeV to 20.0 MeV
# Zn-67	10.0 µeV to 20.0 MeV
# Zn-68	10.0 µeV to 20.0 MeV
# Zn-69	10.0 µeV to 20.0 MeV
# Zn-70	10.0 µeV to 20.0 MeV
# Ga-69	10.0 µeV to 20.0 MeV
# Ga-70	10.0 µeV to 20.0 MeV
# Ga-71	10.0 µeV to 20.0 MeV
# Ge-70	10.0 µeV to 20.0 MeV
# Ge-71	10.0 µeV to 20.0 MeV
# Ge-72	10.0 µeV to 20.0 MeV
# Ge-73	10.0 µeV to 20.0 MeV
# Ge-74	10.0 µeV to 20.0 MeV
# Ge-75	10.0 µeV to 20.0 MeV
# Ge-76	10.0 µeV to 20.0 MeV
# As-73	10.0 µeV to 20.0 MeV
# As-74	10.0 µeV to 20.0 MeV
# As-75	10.0 µeV to 20.0 MeV
# Se-74	10.0 µeV to 20.0 MeV
# Se-75	10.0 µeV to 200.0 MeV
# Se-76	10.0 µeV to 20.0 MeV
# Se-77	10.0 µeV to 20.0 MeV
# Se-78	10.0 µeV to 20.0 MeV
# Se-79	10.0 µeV to 20.0 MeV
# Se-80	10.0 µeV to 20.0 MeV
# Se-81	10.0 µeV to 20.0 MeV
# Se-82	10.0 µeV to 20.0 MeV
# Br-79	10.0 µeV to 20.0 MeV
# Br-80	10.0 µeV to 20.0 MeV
# Br-81	10.0 µeV to 20.0 MeV
# Kr-78	10.0 µeV to 20.0 MeV
# Kr-79	10.0 µeV to 20.0 MeV
# Kr-80	10.0 µeV to 20.0 MeV
# Kr-81	10.0 µeV to 200.0 MeV
# Kr-82	10.0 µeV to 20.0 MeV
# Kr-83	10.0 µeV to 20.0 MeV
# Kr-84	10.0 µeV to 20.0 MeV
# Kr-85	10.0 µeV to 20.0 MeV
# Kr-86	10.0 µeV to 20.0 MeV
# Rb-85	10.0 µeV to 20.0 MeV
# Rb-86	10.0 µeV to 20.0 MeV
# Rb-87	10.0 µeV to 20.0 MeV
# Sr-84	10.0 µeV to 20.0 MeV
# Sr-85	10.0 µeV to 20.0 MeV
# Sr-86	10.0 µeV to 20.0 MeV
# Sr-87	10.0 µeV to 20.0 MeV
# Sr-88	10.0 µeV to 20.0 MeV
# Sr-89	10.0 µeV to 20.0 MeV
# Sr-90	10.0 µeV to 20.0 MeV
# Y-89	10.0 µeV to 20.0 MeV
# Y-90	10.0 µeV to 20.0 MeV
# Y-91	10.0 µeV to 20.0 MeV
# Zr-90	10.0 µeV to 20.0 MeV
# Zr-91	10.0 µeV to 20.0 MeV
# Zr-92	10.0 µeV to 20.0 MeV
# Zr-93	10.0 µeV to 20.0 MeV
# Zr-94	10.0 µeV to 20.0 MeV
# Zr-95	10.0 µeV to 20.0 MeV
# Zr-96	10.0 µeV to 20.0 MeV
# Nb-93	10.0 µeV to 150.0 MeV
# Nb-94	10.0 µeV to 20.0 MeV
# Nb-95	10.0 µeV to 20.0 MeV
# Mo-92	10.0 µeV to 20.0 MeV
# Mo-93	10.0 µeV to 200.0 MeV
# Mo-94	10.0 µeV to 20.0 MeV
# Mo-95	10.0 µeV to 20.0 MeV
# Mo-96	10.0 µeV to 20.0 MeV
# Mo-97	10.0 µeV to 20.0 MeV
# Mo-98	10.0 µeV to 20.0 MeV
# Mo-99	10.0 µeV to 20.0 MeV
# Mo-100	10.0 µeV to 20.0 MeV
# Tc-98	10.0 µeV to 200.0 MeV
# Tc-99	10.0 µeV to 20.0 MeV
# Ru-96	10.0 µeV to 20.0 MeV
# Ru-97	10.0 µeV to 200.0 MeV
# Ru-98	10.0 µeV to 20.0 MeV
# Ru-99	10.0 µeV to 20.0 MeV
# Ru-100	10.0 µeV to 20.0 MeV
# Ru-101	10.0 µeV to 20.0 MeV
# Ru-102	10.0 µeV to 20.0 MeV
# Ru-103	10.0 µeV to 20.0 MeV
# Ru-104	10.0 µeV to 20.0 MeV
# Ru-105	10.0 µeV to 20.0 MeV
# Ru-106	10.0 µeV to 20.0 MeV
# Rh-103	10.0 µeV to 20.0 MeV
# Rh-104	10.0 µeV to 20.0 MeV
# Rh-105	10.0 µeV to 20.0 MeV
# Pd-102	10.0 µeV to 30.0 MeV
# Pd-103	10.0 µeV to 20.0 MeV
# Pd-104	10.0 µeV to 30.0 MeV
# Pd-105	10.0 µeV to 20.0 MeV
# Pd-106	10.0 µeV to 30.0 MeV
# Pd-107	10.0 µeV to 20.0 MeV
# Pd-108	10.0 µeV to 30.0 MeV
# Pd-109	10.0 µeV to 20.0 MeV
# Pd-110	10.0 µeV to 30.0 MeV
# Ag-107	10.0 µeV to 20.0 MeV
# Ag-108	10.0 µeV to 20.0 MeV
# Ag-109	10.0 µeV to 20.0 MeV
# Ag-111	10.0 µeV to 20.0 MeV
# Ag-112	10.0 µeV to 20.0 MeV
# Ag-113	10.0 µeV to 20.0 MeV
# Ag-114	10.0 µeV to 20.0 MeV
# Ag-115	10.0 µeV to 20.0 MeV
# Ag-116	10.0 µeV to 20.0 MeV
# Ag-117	10.0 µeV to 20.0 MeV
# Cd-106	10.0 µeV to 20.0 MeV
# Cd-107	10.0 µeV to 20.0 MeV
# Cd-108	10.0 µeV to 20.0 MeV
# Cd-109	10.0 µeV to 200.0 MeV
# Cd-110	10.0 µeV to 20.0 MeV
# Cd-111	10.0 µeV to 20.0 MeV
# Cd-112	10.0 µeV to 20.0 MeV
# Cd-113	10.0 µeV to 20.0 MeV
# Cd-114	10.0 µeV to 20.0 MeV
# Cd-116	10.0 µeV to 20.0 MeV
# In-113	10.0 µeV to 20.0 MeV
# In-114	10.0 µeV to 20.0 MeV
# In-115	10.0 µeV to 20.0 MeV
# Sn-112	10.0 µeV to 20.0 MeV
# Sn-113	10.0 µeV to 20.0 MeV
# Sn-114	10.0 µeV to 20.0 MeV
# Sn-115	10.0 µeV to 20.0 MeV
# Sn-116	10.0 µeV to 20.0 MeV
# Sn-117	10.0 µeV to 20.0 MeV
# Sn-118	10.0 µeV to 20.0 MeV
# Sn-119	10.0 µeV to 20.0 MeV
# Sn-120	10.0 µeV to 20.0 MeV
# Sn-122	10.0 µeV to 20.0 MeV
# Sn-123	10.0 µeV to 20.0 MeV
# Sn-124	10.0 µeV to 20.0 MeV
# Sn-125	10.0 µeV to 20.0 MeV
# Sn-126	10.0 µeV to 20.0 MeV
# Sb-121	10.0 µeV to 20.0 MeV
# Sb-122	10.0 µeV to 20.0 MeV
# Sb-123	10.0 µeV to 20.0 MeV
# Sb-124	10.0 µeV to 20.0 MeV
# Sb-125	10.0 µeV to 20.0 MeV
# Sb-126	10.0 µeV to 20.0 MeV
# Te-120	10.0 µeV to 20.0 MeV
# Te-121	10.0 µeV to 20.0 MeV
# Te-122	10.0 µeV to 20.0 MeV
# Te-123	10.0 µeV to 20.0 MeV
# Te-124	10.0 µeV to 20.0 MeV
# Te-125	10.0 µeV to 20.0 MeV
# Te-126	10.0 µeV to 20.0 MeV
# Te-128	10.0 µeV to 20.0 MeV
# Te-130	10.0 µeV to 20.0 MeV
# Te-131	10.0 µeV to 20.0 MeV
# Te-132	10.0 µeV to 20.0 MeV
# I-127	10.0 µeV to 30.0 MeV
# I-128	10.0 µeV to 20.0 MeV
# I-129	10.0 µeV to 20.0 MeV
# I-130	10.0 µeV to 20.0 MeV
# I-131	10.0 µeV to 20.0 MeV
# I-132	10.0 µeV to 20.0 MeV
# I-133	10.0 µeV to 20.0 MeV
# I-134	10.0 µeV to 20.0 MeV
# I-135	10.0 µeV to 20.0 MeV
# Xe-123	10.0 µeV to 20.0 MeV
# Xe-124	10.0 µeV to 20.0 MeV
# Xe-125	10.0 µeV to 20.0 MeV
# Xe-126	10.0 µeV to 20.0 MeV
# Xe-127	10.0 µeV to 20.0 MeV
# Xe-128	10.0 µeV to 20.0 MeV
# Xe-129	10.0 µeV to 20.0 MeV
# Xe-130	10.0 µeV to 20.0 MeV
# Xe-131	10.0 µeV to 20.0 MeV
# Xe-132	10.0 µeV to 20.0 MeV
# Xe-133	10.0 µeV to 20.0 MeV
# Xe-134	10.0 µeV to 20.0 MeV
# Xe-135	10.0 µeV to 20.0 MeV
# Xe-136	10.0 µeV to 20.0 MeV
# Cs-133	10.0 µeV to 20.0 MeV
# Cs-134	10.0 µeV to 20.0 MeV
# Cs-135	10.0 µeV to 20.0 MeV
# Cs-136	10.0 µeV to 20.0 MeV
# Cs-137	10.0 µeV to 20.0 MeV
# Ba-130	10.0 µeV to 20.0 MeV
# Ba-131	10.0 µeV to 20.0 MeV
# Ba-132	10.0 µeV to 20.0 MeV
# Ba-133	10.0 µeV to 20.0 MeV
# Ba-134	10.0 µeV to 20.0 MeV
# Ba-135	10.0 µeV to 20.0 MeV
# Ba-136	10.0 µeV to 20.0 MeV
# Ba-137	10.0 µeV to 20.0 MeV
# Ba-138	10.0 µeV to 20.0 MeV
# Ba-139	10.0 µeV to 20.0 MeV
# Ba-140	10.0 µeV to 20.0 MeV
# La-138	10.0 µeV to 20.0 MeV
# La-139	10.0 µeV to 20.0 MeV
# La-140	10.0 µeV to 20.0 MeV
# Ce-136	10.0 µeV to 20.0 MeV
# Ce-137	10.0 µeV to 20.0 MeV
# Ce-138	10.0 µeV to 20.0 MeV
# Ce-139	10.0 µeV to 20.0 MeV
# Ce-140	10.0 µeV to 20.0 MeV
# Ce-141	10.0 µeV to 20.0 MeV
# Ce-142	10.0 µeV to 20.0 MeV
# Ce-143	10.0 µeV to 20.0 MeV
# Ce-144	10.0 µeV to 20.0 MeV
# Pr-141	10.0 µeV to 20.0 MeV
# Pr-142	10.0 µeV to 20.0 MeV
# Pr-143	10.0 µeV to 20.0 MeV
# Nd-142	10.0 µeV to 20.0 MeV
# Nd-143	10.0 µeV to 20.0 MeV
# Nd-144	10.0 µeV to 20.0 MeV
# Nd-145	10.0 µeV to 20.0 MeV
# Nd-146	10.0 µeV to 20.0 MeV
# Nd-147	10.0 µeV to 20.0 MeV
# Nd-148	10.0 µeV to 20.0 MeV
# Nd-149	10.0 µeV to 20.0 MeV
# Nd-150	10.0 µeV to 20.0 MeV
# Pm-143	10.0 µeV to 200.0 MeV
# Pm-144	10.0 µeV to 200.0 MeV
# Pm-145	10.0 µeV to 200.0 MeV
# Pm-146	10.0 µeV to 20.0 MeV
# Pm-147	10.0 µeV to 20.0 MeV
# Pm-148	10.0 µeV to 20.0 MeV
# Pm-149	10.0 µeV to 20.0 MeV
# Pm-150	10.0 µeV to 20.0 MeV
# Pm-151	10.0 µeV to 20.0 MeV
# Sm-144	10.0 µeV to 20.0 MeV
# Sm-145	10.0 µeV to 200.0 MeV
# Sm-146	10.0 µeV to 20.0 MeV
# Sm-147	10.0 µeV to 20.0 MeV
# Sm-148	10.0 µeV to 20.0 MeV
# Sm-149	10.0 µeV to 20.0 MeV
# Sm-150	10.0 µeV to 20.0 MeV
# Sm-151	10.0 µeV to 20.0 MeV
# Sm-152	10.0 µeV to 20.0 MeV
# Sm-153	10.0 µeV to 20.0 MeV
# Sm-154	10.0 µeV to 20.0 MeV
# Eu-151	10.0 µeV to 20.0 MeV
# Eu-152	10.0 µeV to 20.0 MeV
# Eu-153	10.0 µeV to 20.0 MeV
# Eu-154	10.0 µeV to 20.0 MeV
# Eu-155	10.0 µeV to 20.0 MeV
# Eu-156	10.0 µeV to 20.0 MeV
# Eu-157	10.0 µeV to 20.0 MeV
# Gd-152	10.0 µeV to 20.0 MeV
# Gd-153	10.0 µeV to 20.0 MeV
# Gd-154	10.0 µeV to 20.0 MeV
# Gd-155	10.0 µeV to 20.0 MeV
# Gd-156	10.0 µeV to 20.0 MeV
# Gd-157	10.0 µeV to 20.0 MeV
# Gd-158	10.0 µeV to 20.0 MeV
# Gd-159	10.0 µeV to 20.0 MeV
# Gd-160	10.0 µeV to 20.0 MeV
# Tb-158	10.0 µeV to 20.0 MeV
# Tb-159	10.0 µeV to 20.0 MeV
# Tb-160	10.0 µeV to 20.0 MeV
# Tb-161	10.0 µeV to 20.0 MeV
# Dy-154	10.0 µeV to 20.0 MeV
# Dy-155	10.0 µeV to 20.0 MeV
# Dy-156	10.0 µeV to 20.0 MeV
# Dy-157	10.0 µeV to 20.0 MeV
# Dy-158	10.0 µeV to 20.0 MeV
# Dy-159	10.0 µeV to 20.0 MeV
# Dy-160	10.0 µeV to 20.0 MeV
# Dy-161	10.0 µeV to 20.0 MeV
# Dy-162	10.0 µeV to 20.0 MeV
# Dy-163	10.0 µeV to 20.0 MeV
# Dy-164	10.0 µeV to 20.0 MeV
# Ho-165	10.0 µeV to 30.0 MeV
# Er-162	10.0 µeV to 20.0 MeV
# Er-163	10.0 µeV to 20.0 MeV
# Er-164	10.0 µeV to 20.0 MeV
# Er-165	10.0 µeV to 20.0 MeV
# Er-166	10.0 µeV to 20.0 MeV
# Er-167	10.0 µeV to 20.0 MeV
# Er-168	10.0 µeV to 20.0 MeV
# Er-169	10.0 µeV to 20.0 MeV
# Er-170	10.0 µeV to 20.0 MeV
# Tm-168	10.0 µeV to 30.0 MeV
# Tm-169	10.0 µeV to 30.0 MeV
# Tm-170	10.0 µeV to 30.0 MeV
# Tm-171	10.0 µeV to 20.0 MeV
# Yb-168	10.0 µeV to 20.0 MeV
# Yb-169	10.0 µeV to 20.0 MeV
# Yb-170	10.0 µeV to 20.0 MeV
# Yb-171	10.0 µeV to 20.0 MeV
# Yb-172	10.0 µeV to 20.0 MeV
# Yb-173	10.0 µeV to 20.0 MeV
# Yb-174	10.0 µeV to 20.0 MeV
# Yb-175	10.0 µeV to 20.0 MeV
# Yb-176	10.0 µeV to 20.0 MeV
# Lu-175	10.0 µeV to 20.0 MeV
# Lu-176	10.0 µeV to 20.0 MeV
# Hf-174	10.0 µeV to 20.0 MeV
# Hf-175	10.0 µeV to 20.0 MeV
# Hf-176	10.0 µeV to 20.0 MeV
# Hf-177	10.0 µeV to 20.0 MeV
# Hf-178	10.0 µeV to 20.0 MeV
# Hf-179	10.0 µeV to 20.0 MeV
# Hf-180	10.0 µeV to 20.0 MeV
# Hf-181	10.0 µeV to 20.0 MeV
# Hf-182	10.0 µeV to 20.0 MeV
# Ta-180	10.0 µeV to 20.0 MeV
# Ta-181	10.0 µeV to 20.0 MeV
# Ta-182	10.0 µeV to 20.0 MeV
# W-180	10.0 µeV to 150.0 MeV
# W-181	10.0 µeV to 20.0 MeV
# W-182	10.0 µeV to 150.0 MeV
# W-183	10.0 µeV to 150.0 MeV
# W-184	10.0 µeV to 150.0 MeV
# W-185	10.0 µeV to 20.0 MeV
# W-186	10.0 µeV to 150.0 MeV
# Re-185	10.0 µeV to 20.0 MeV
# Re-187	10.0 µeV to 20.0 MeV
# Os-184	10.0 µeV to 20.0 MeV
# Os-185	10.0 µeV to 20.0 MeV
# Os-186	10.0 µeV to 20.0 MeV
# Os-187	10.0 µeV to 20.0 MeV
# Os-188	10.0 µeV to 20.0 MeV
# Os-189	10.0 µeV to 20.0 MeV
# Os-190	10.0 µeV to 20.0 MeV
# Os-191	10.0 µeV to 200.0 MeV
# Os-192	10.0 µeV to 20.0 MeV
# Ir-191	10.0 µeV to 20.0 MeV
# Ir-192	10.0 µeV to 200.0 MeV
# Ir-193	10.0 µeV to 20.0 MeV
# Pt-190	10.0 µeV to 200.0 MeV
# Pt-191	10.0 µeV to 200.0 MeV
# Pt-192	10.0 µeV to 200.0 MeV
# Pt-193	10.0 µeV to 200.0 MeV
# Pt-194	10.0 µeV to 200.0 MeV
# Pt-195	10.0 µeV to 200.0 MeV
# Pt-196	10.0 µeV to 200.0 MeV
# Pt-197	10.0 µeV to 200.0 MeV
# Pt-198	10.0 µeV to 200.0 MeV
# Au-197	10.0 µeV to 30.0 MeV
# Hg-196	10.0 µeV to 150.0 MeV
# Hg-197	10.0 µeV to 20.0 MeV
# Hg-198	10.0 µeV to 150.0 MeV
# Hg-199	10.0 µeV to 150.0 MeV
# Hg-200	10.0 µeV to 150.0 MeV
# Hg-201	10.0 µeV to 150.0 MeV
# Hg-202	10.0 µeV to 150.0 MeV
# Hg-203	10.0 µeV to 200.0 MeV
# Hg-204	10.0 µeV to 150.0 MeV
# Tl-203	10.0 µeV to 30.0 MeV
# Tl-204	10.0 µeV to 200.0 MeV
# Tl-205	10.0 µeV to 30.0 MeV
# Pb-204	10.0 µeV to 200.0 MeV
# Pb-205	10.0 µeV to 200.0 MeV
# Pb-206	10.0 µeV to 200.0 MeV
# Pb-207	10.0 µeV to 200.0 MeV
# Pb-208	10.0 µeV to 150.0 MeV
# Bi-209	10.0 µeV to 150.0 MeV
# Po-208	10.0 µeV to 200.0 MeV
# Po-209	10.0 µeV to 20.0 MeV
# Po-210	10.0 µeV to 200.0 MeV
# Ra-223	10.0 µeV to 20.0 MeV
# Ra-224	10.0 µeV to 20.0 MeV
# Ra-225	10.0 µeV to 20.0 MeV
# Ra-226	10.0 µeV to 20.0 MeV
# Ac-225	10.0 µeV to 20.0 MeV
# Ac-226	10.0 µeV to 20.0 MeV
# Ac-227	10.0 µeV to 20.0 MeV
# Th-227	10.0 µeV to 20.0 MeV
# Th-228	10.0 µeV to 20.0 MeV
# Th-229	10.0 µeV to 20.0 MeV
# Th-230	10.0 µeV to 20.0 MeV
# Th-231	10.0 µeV to 20.0 MeV
# Th-232	10.0 µeV to 60.0 MeV
# Th-233	10.0 µeV to 20.0 MeV
# Th-234	10.0 µeV to 20.0 MeV
# Pa-229	10.0 µeV to 20.0 MeV
# Pa-230	10.0 µeV to 20.0 MeV
# Pa-231	10.0 µeV to 60.0 MeV
# Pa-232	10.0 µeV to 20.0 MeV
# Pa-233	10.0 µeV to 60.0 MeV
# U-230	10.0 µeV to 20.0 MeV
# U-231	10.0 µeV to 20.0 MeV
# U-232	10.0 µeV to 20.0 MeV
# U-233	10.0 µeV to 20.0 MeV
# U-234	10.0 µeV to 30.0 MeV
# U-235	10.0 µeV to 30.0 MeV
# U-236	10.0 µeV to 30.0 MeV
# U-237	10.0 µeV to 30.0 MeV
# U-238	10.0 µeV to 30.0 MeV
# U-239	10.0 µeV to 30.0 MeV
# U-240	10.0 µeV to 30.0 MeV
# U-241	10.0 µeV to 30.0 MeV
# Np-234	10.0 µeV to 20.0 MeV
# Np-235	10.0 µeV to 20.0 MeV
# Np-236	10.0 µeV to 20.0 MeV
# Np-237	10.0 µeV to 20.0 MeV
# Np-238	10.0 µeV to 20.0 MeV
# Np-239	10.0 µeV to 20.0 MeV
# Pu-236	10.0 µeV to 20.0 MeV
# Pu-237	10.0 µeV to 20.0 MeV
# Pu-238	10.0 µeV to 30.0 MeV
# Pu-239	10.0 µeV to 20.0 MeV
# Pu-240	10.0 µeV to 30.0 MeV
# Pu-241	10.0 µeV to 20.0 MeV
# Pu-242	10.0 µeV to 20.0 MeV
# Pu-243	10.0 µeV to 20.0 MeV
# Pu-244	10.0 µeV to 20.0 MeV
# Pu-245	10.0 µeV to 20.0 MeV
# Pu-246	10.0 µeV to 20.0 MeV
# Am-240	10.0 µeV to 20.0 MeV
# Am-241	10.0 µeV to 30.0 MeV
# Am-242	10.0 µeV to 20.0 MeV
# Am-243	10.0 µeV to 30.0 MeV
# Am-244	10.0 µeV to 20.0 MeV
# Cm-240	10.0 µeV to 20.0 MeV
# Cm-241	10.0 µeV to 20.0 MeV
# Cm-242	10.0 µeV to 20.0 MeV
# Cm-243	10.0 µeV to 20.0 MeV
# Cm-244	10.0 µeV to 20.0 MeV
# Cm-245	10.0 µeV to 20.0 MeV
# Cm-246	10.0 µeV to 20.0 MeV
# Cm-247	10.0 µeV to 20.0 MeV
# Cm-248	10.0 µeV to 20.0 MeV
# Cm-249	10.0 µeV to 20.0 MeV
# Cm-250	10.0 µeV to 20.0 MeV
# Bk-245	10.0 µeV to 20.0 MeV
# Bk-246	10.0 µeV to 20.0 MeV
# Bk-247	10.0 µeV to 20.0 MeV
# Bk-248	10.0 µeV to 20.0 MeV
# Bk-249	10.0 µeV to 20.0 MeV
# Bk-250	10.0 µeV to 20.0 MeV
# Cf-246	10.0 µeV to 20.0 MeV
# Cf-247	10.0 µeV to 20.0 MeV
# Cf-248	10.0 µeV to 20.0 MeV
# Cf-249	10.0 µeV to 20.0 MeV
# Cf-250	10.0 µeV to 20.0 MeV
# Cf-251	10.0 µeV to 20.0 MeV
# Cf-252	10.0 µeV to 20.0 MeV
# Cf-253	10.0 µeV to 20.0 MeV
# Cf-254	10.0 µeV to 20.0 MeV
# Es-251	10.0 µeV to 20.0 MeV
# Es-252	10.0 µeV to 20.0 MeV
# Es-253	10.0 µeV to 20.0 MeV
# Es-254	10.0 µeV to 20.0 MeV
# Es-255	10.0 µeV to 20.0 MeV
# Fm-255	10.0 µeV to 20.0 MeV
# Total number of isotopes: 533

# %% [markdown]
# We access all available isotopes using the `cross_section.avail` function.

# %%
available_isotopes = cross_section.avail()
print(f"available_isotopes = [{available_isotopes[0]}, {available_isotopes[1]}, ..., {available_isotopes[-2]}, {available_isotopes[-1]}]")
print(f"Number of isotopes = {len(available_isotopes)}")
# Out:
# available_isotopes = [H-1, H-2, ..., Es-255, Fm-255]
# Number of isotopes = 533

# %% [markdown]
# You can restrict the displayed isotopes by `cross_section.info` using the `isotopes` optional argument.
# Below we subselect all the uranium isotopes.

# %%
# restrict all
isotopes_U = [iso for iso in available_isotopes if iso.split("-")[0] == "U"]
print("\nUranium Isotopes:")
cross_section.info(isotopes=isotopes_U)
# Out:
# Uranium Isotopes:
# U-230	10.0 µeV to 20.0 MeV
# U-231	10.0 µeV to 20.0 MeV
# U-232	10.0 µeV to 20.0 MeV
# U-233	10.0 µeV to 20.0 MeV
# U-234	10.0 µeV to 30.0 MeV
# U-235	10.0 µeV to 30.0 MeV
# U-236	10.0 µeV to 30.0 MeV
# U-237	10.0 µeV to 30.0 MeV
# U-238	10.0 µeV to 30.0 MeV
# U-239	10.0 µeV to 30.0 MeV
# U-240	10.0 µeV to 30.0 MeV
# U-241	10.0 µeV to 30.0 MeV

# %% [markdown]
# Generate and Plot a Cross Section Dictionary Object `XSDict`
# ------------------------------------------------------------
#
# First we setup the time-of-flight array and requested isotopes list.

# %%
Δt = 0.30  # bin width [μs]
flight_path_length = 10  # [m]
t_F = np.arange(72, 720, Δt)  # time-of-flight array [μs]
isotopes = ["U-235", "U-238"]

# %% [markdown]
# Create a cross section dictionary object `XSDict`.

# %%
D = cross_section.XSDict(isotopes, t_F, flight_path_length)
print(D)
# Out:
# <class 'trinidi.cross_section.XSDict'>
#     isotopes = ['U-235', 'U-238']
#     N_m = 2
#
#     t_F = [72.000 μs, ..., 719.700 μs]
#     Δt = 0.300 μs
#     N_F = 2160
#     flight_path_length = 10.000 m
#     E = [100.830 eV, ..., 1.009 eV]
#
#     samples_per_bin = 10
#
#     values.shape = (2, 2160) = (N_m, N_F)

# %% [markdown]
# The `np.ndarray` `D.values` is a matrix of size `N_m x N_F` (`number of isotopes` `x` `number of time-of-flight bins`) that contains the cross section values.

# %%
print(f"{D.values.shape = }")
# Out:
# D.values.shape = (2, 2160)

# %% [markdown]
# You can plot the dictionary with the `XSDict.plot` function.
#
# - The optional argument `function_of_energy=False` [default] allows plotting it as a function of time-of-flight while `function_of_energy=True` plots it as a function of energy.

# %%
fig, ax = plt.subplots(2, 1, figsize=[12, 8], sharex=False)
ax = np.atleast_1d(ax)
D.plot(ax[0])
D.plot(ax[1], function_of_energy=False)
fig.suptitle("Plotting Cross Section Dictionary by TOF and Energy")
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0, rect=(0, 0, 1, 0.95))
plt.show()

# %% [markdown]
# Creating a Compound Material Cross Section Dictionary
# -----------------------------------------------------
#
# When reconstructing a sample with isotopes in known proportions, we recommend combining the corresponding isotopes according to their abundances and treating it as a compound material.
#
# For example, below we show how we construct a gold and tungsten (`Au`, `W`) cross section dictionary. Gold is practically 100% `Au-197` so no action is necessary. However, elemental tungsten consists of several isotopes,
#
# - `W-180` (0.12%)
# - `W-182` (26.5%)
# - `W-183` (14.3%)
# - `W-184` (30.6%)
# - `W-186` (28.4%)
#
# which we want to combine into a single entry with the use of the `XSDict.merge` function.

# %% [markdown]
# We start out with the `XSDict` using all isotopes. The `D_full` object will stay untouched and used for later comparison.

# %%
isotopes_full = ["Au-197", "W-180", "W-182", "W-183", "W-184", "W-186"]
D_full = cross_section.XSDict(isotopes_full, t_F, flight_path_length)

# %% [markdown]
# We now define the arguments for the `XSDict.merge` function.

# %%
merge_isotopes = ["W-180", "W-182", "W-183", "W-184", "W-186"]
merge_weights = [0.0012, 0.265, 0.143, 0.306, 0.284]
new_key = "W"

# %% [markdown]
# Below, we generate the modified `XSDict` object, `D_new` from a copy of `D_full`.

# %%
D_new = deepcopy(D_full)
isotopes_new = D_new.merge(merge_isotopes, merge_weights, new_key)
print(f"New isotope list: {isotopes_new}")
print(D_new)
# Out:
# New isotope list: ['Au-197', 'W']
# <class 'trinidi.cross_section.XSDict'>
#     isotopes = ['Au-197', 'W']
#     N_m = 2
#
#     t_F = [72.000 μs, ..., 719.700 μs]
#     Δt = 0.300 μs
#     N_F = 2160
#     flight_path_length = 10.000 m
#     E = [100.830 eV, ..., 1.009 eV]
#
#     samples_per_bin = 10
#
#     values.shape = (2, 2160) = (N_m, N_F)

# %% [markdown]
# The `merge_isotopes` cross sections are combined using a weighted sum using the `merge_weights`. All previous isotope keys, `["W-180", "W-182", "W-183", "W-184", "W-186"]`, will be replaced by the `new_key`, `"W"`, which is defined by the user.
#
# (Note that the updated list `XSDict.isotopes` is now not necessarily strictly isotopes since `"W"` is not an isotope. After creation this list primarily serves for plotting and identification of the entries.)

# %% [markdown]
# Below we plot and compare the resulting `XSDict` objects.

# %%
fig, ax = plt.subplots(2, 1, figsize=[12, 8], sharex=True)
ax = np.atleast_1d(ax)
D_full.plot(ax[0])
D_new.plot(ax[1])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0, rect=(0, 0, 1, 0.95))
fig.suptitle("Plotting Full and Merged Cross Section Dictionaries")
plt.show()
